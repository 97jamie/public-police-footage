# %%
from IPython.display import Audio
from whisper_test import test_all, sample_one, test_one
import warnings

# %% [markdown]
# Compute Whisper turbo WER for a single video, where the OCR extracted caption is considered to be the reference. This can be run on CPU (e.g. on a laptop), but will take about 10min per video)

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    test_one("segment_test/UCager4c99nqQAmdiB7WMZhQ", "output/batch_hand/UCager4c99nqQAmdiB7WMZhQ/RL_30kV6VWM.json")
# Out:
# Processing output/batch_hand/UCager4c99nqQAmdiB7WMZhQ/RL_30kV6VWM.json
# 75it [09:23,  7.51s/it]
# RL_30kV6VWM 75 0.8769574944071589

# %% [markdown]
# "test_all" will compute Whisper turbo WER for all channels and videos in a directory. This will take a long time to run over the training set but is runnable over the hand-cleaned set

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    test_all("segment_test", "output/batch_hand")
# Out:
# Processing q6jhyIcumG0.json
# Processing RL_30kV6VWM.json
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/anjalief/miniconda3/envs/police/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3505, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/z_/chbwf3hd2js6hty6qjc2rpdh0000gn/T/ipykernel_47425/3227334270.py", line 5, in <module>
#     results = test_all("segment_test", "output/batch_hand")
#   File "/Users/anjalief/public-police-footage/whisper_test.py", line 33, in test_all
#   File "/Users/anjalief/miniconda3/envs/police/lib/python3.9/site-packages/whisper/transcribe.py", line 279, in transcribe
#     result: DecodingResult = decode_with_fallback(mel_segment)
#   File "/Users/anjalief/miniconda3/envs/police/lib/python3.9/site-packages/whisper/transcribe.py", line 195, in decode_with_fallback
# ...

# %% [markdown]
# "sample_one" will randomly grab one audio clip and it's caption for spot-checking the data.

# %%
segment_path, anno = sample_one("segment_test", "output/batch_hand")

print(anno)
Audio(filename=segment_path, autoplay=True)
# Out:
# UCedDHcqSgiaOk4J0vkAC5LQ q6jhyIcumG0_38.wav
# {'start_time': 1092.78546, 'end_time': 1093.60968, 'text': "he's holding?", 'speaker': 'Officer'}
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
